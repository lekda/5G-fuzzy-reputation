# %% [markdown]
# ## Multiseeds plots

# %%
from plot_label import plot_negative_interactions_overtime,plot_cumulative_negative_interactions
from pathlib import Path

exponential = Path(f"../results/fuzzy/exponential_no_failure/")
exponential_failure = Path("../results/fuzzy/exponential_failure/")
plot_negative_interactions_overtime([("exponential", exponential),("exponential_failure", exponential_failure)], fuzzy=True, multiseed=True)
plot_cumulative_negative_interactions([("exponential", exponential)],fuzzy=True, multiseed=True)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 6
#       4 exponential = Path(f"../results/fuzzy/exponential_no_failure/")
#       5 exponential_failure = Path("../results/fuzzy/exponential_failure/")
# ----> 6 plot_negative_interactions_overtime([("exponential", exponential),("exponential_failure", exponential_failure)], fuzzy=True, multiseed=True)
#       7 plot_cumulative_negative_interactions([("exponential", exponential)],fuzzy=True, multiseed=True)
#
# File ~/base-reputation-system/plotter/plot_label.py:131, in plot_negative_interactions_overtime(paths, multiseed, fuzzy)
#     129 for label, path in paths:
#     130     if fuzzy:
# --> 131         n_i_overtime = fuzzy_load_negative_overtime(Path(path), multiseed)
#     132     else:
#     133         n_i_overtime = load_negative_overtime(Path(path), multiseed)
#
# ...

# %% [markdown]
# ## Comparing differents decay function

# %%
import tabulate
from pathlib import Path
from plot_utils import load_total_positive,load_total_negative,load_total_negative,load_total_interactions

exponential = Path("../results/multirun/2024-06-11/11-39-05/0")
single = Path("../results/multirun/2024-06-11/11-39-05/1")
double = Path("../results/multirun/2024-06-11/11-39-05/2")
adaptive = Path("../results/multirun/2024-06-11/11-39-05/3")

data = [ ["","Successes","Failures","Failure ratio (%)","Expected failures", "Ratio (%) of expected failures","Total" ],
         ["Exponential",load_total_positive(exponential),load_total_negative(exponential),round( 100* load_total_negative(exponential)/load_total_interactions(exponential),2),load_total_negative(exponential,expected=True),round( 100* load_total_negative(exponential,expected=True)/load_total_negative(exponential),ndigits=2),load_total_interactions(exponential)],
         ["Single",load_total_positive(single),load_total_negative(single),round( 100* load_total_negative(single)/load_total_interactions(single),2),load_total_negative(single,expected=True),round( 100* load_total_negative(single,expected=True)/load_total_negative(single),ndigits=2),load_total_interactions(single)],
         ["Double",load_total_positive(double),load_total_negative(double),round( 100* load_total_negative(double)/load_total_interactions(double),2),load_total_negative(double,expected=True),round( 100* load_total_negative(double,expected=True)/load_total_negative(double),ndigits=2),load_total_interactions(double)],
         ["Adaptive",load_total_positive(adaptive),load_total_negative(adaptive),round( 100* load_total_negative(adaptive)/load_total_interactions(adaptive),2),load_total_negative(adaptive,expected=True),round( 100* load_total_negative(adaptive,expected=True)/load_total_negative(adaptive),ndigits=2),load_total_interactions(adaptive)],

         ]
table = tabulate.tabulate(data, tablefmt='html')
table
# Out:
# '<table>\n<tbody>\n<tr><td>           </td><td>Successes</td><td>Failures</td><td>Failure ratio (%)</td><td>Expected failures</td><td>Ratio (%) of expected failures</td><td>Total</td></tr>\n<tr><td>Exponential</td><td>1429     </td><td>71      </td><td>4.73             </td><td>0                </td><td>0.0                           </td><td>1500 </td></tr>\n<tr><td>Single     </td><td>1410     </td><td>90      </td><td>6.0              </td><td>1                </td><td>1.11                          </td><td>1500 </td></tr>\n<tr><td>Double     </td><td>1419     </td><td>81      </td><td>5.4              </td><td>0                </td><td>0.0                           </td><td>1500 </td></tr>\n<tr><td>Adaptive   </td><td>1409     </td><td>91      </td><td>6.07             </td><td>0                </td><td>0.0                           </td><td>1500 </td></tr>\n</tbody>\n</table>'

# %% [markdown]
# ### Success rate on short outage (outage duration = 2 ) scenario

# %%
import tabulate
from pathlib import Path
from plot_utils import load_total_positive,load_total_negative,load_total_negative,load_total_interactions

date_time = "2024-06-11/11-43-54"

exponential = Path(f"../results/multirun/{date_time}/0")
single = Path(f"../results/multirun/{date_time}/1")
double = Path(f"../results/multirun/{date_time}/2")
adaptive = Path(f"../results/multirun/{date_time}/3")

data = [ ["","Successes","Failures","Failure ratio (%)","Expected failures", "Ratio (%) of expected failures","Total" ],
         ["Exponential",load_total_positive(exponential),load_total_negative(exponential),round( 100* load_total_negative(exponential)/load_total_interactions(exponential),2),load_total_negative(exponential,expected=True),round( 100* load_total_negative(exponential,expected=True)/load_total_negative(exponential),ndigits=2),load_total_interactions(exponential)],
         ["Single",load_total_positive(single),load_total_negative(single),round( 100* load_total_negative(single)/load_total_interactions(single),2),load_total_negative(single,expected=True),round( 100* load_total_negative(single,expected=True)/load_total_negative(single),ndigits=2),load_total_interactions(single)],
         ["Double",load_total_positive(double),load_total_negative(double),round( 100* load_total_negative(double)/load_total_interactions(double),2),load_total_negative(double,expected=True),round( 100* load_total_negative(double,expected=True)/load_total_negative(double),ndigits=2),load_total_interactions(double)],
         ["Adaptive",load_total_positive(adaptive),load_total_negative(adaptive),round( 100* load_total_negative(adaptive)/load_total_interactions(adaptive),2),load_total_negative(adaptive,expected=True),round( 100* load_total_negative(adaptive,expected=True)/load_total_negative(adaptive),ndigits=2),load_total_interactions(adaptive)],

         ]
table = tabulate.tabulate(data, tablefmt='html')
table
# Out:
# '<table>\n<tbody>\n<tr><td>           </td><td>Successes</td><td>Failures</td><td>Failure ratio (%)</td><td>Expected failures</td><td>Ratio (%) of expected failures</td><td>Total</td></tr>\n<tr><td>Exponential</td><td>1336     </td><td>164     </td><td>10.93            </td><td>20               </td><td>12.2                          </td><td>1500 </td></tr>\n<tr><td>Single     </td><td>1327     </td><td>173     </td><td>11.53            </td><td>24               </td><td>13.87                         </td><td>1500 </td></tr>\n<tr><td>Double     </td><td>1281     </td><td>219     </td><td>14.6             </td><td>106              </td><td>48.4                          </td><td>1500 </td></tr>\n<tr><td>Adaptive   </td><td>1316     </td><td>184     </td><td>12.27            </td><td>28               </td><td>15.22                         </td><td>1500 </td></tr>\n</tbody>\n</table>'

# %% [markdown]
# ### Success rate on longer outage (outage duration = 4 ) scenario

# %%
import tabulate
from pathlib import Path
from plot_utils import load_total_positive,load_total_negative,load_total_negative,load_total_interactions

date_time = "2024-06-12/18-02-43"

exponential = Path(f"../results/multirun/{date_time}/0")
single = Path(f"../results/multirun/{date_time}/1")
double = Path(f"../results/multirun/{date_time}/2")
adaptive = Path(f"../results/multirun/{date_time}/3")

data = [ ["","Successes","Failures","Failure ratio (%)","Expected failures", "Ratio (%) of expected failures","Total" ],
         ["Exponential",load_total_positive(exponential),load_total_negative(exponential),round( 100* load_total_negative(exponential)/load_total_interactions(exponential),2),load_total_negative(exponential,expected=True),round( 100* load_total_negative(exponential,expected=True)/load_total_negative(exponential),ndigits=2),load_total_interactions(exponential)],
         ["Single",load_total_positive(single),load_total_negative(single),round( 100* load_total_negative(single)/load_total_interactions(single),2),load_total_negative(single,expected=True),round( 100* load_total_negative(single,expected=True)/load_total_negative(single),ndigits=2),load_total_interactions(single)],
         ["Double",load_total_positive(double),load_total_negative(double),round( 100* load_total_negative(double)/load_total_interactions(double),2),load_total_negative(double,expected=True),round( 100* load_total_negative(double,expected=True)/load_total_negative(double),ndigits=2),load_total_interactions(double)],
         ["Adaptive",load_total_positive(adaptive),load_total_negative(adaptive),round( 100* load_total_negative(adaptive)/load_total_interactions(adaptive),2),load_total_negative(adaptive,expected=True),round( 100* load_total_negative(adaptive,expected=True)/load_total_negative(adaptive),ndigits=2),load_total_interactions(adaptive)],

         ]
table = tabulate.tabulate(data, tablefmt='html')
table
# Out:
# '<table>\n<tbody>\n<tr><td>           </td><td>Successes</td><td>Failures</td><td>Failure ratio (%)</td><td>Expected failures</td><td>Ratio (%) of expected failures</td><td>Total</td></tr>\n<tr><td>Exponential</td><td>1333     </td><td>167     </td><td>11.13            </td><td>36               </td><td>21.56                         </td><td>1500 </td></tr>\n<tr><td>Single     </td><td>1323     </td><td>177     </td><td>11.8             </td><td>35               </td><td>19.77                         </td><td>1500 </td></tr>\n<tr><td>Double     </td><td>1312     </td><td>188     </td><td>12.53            </td><td>70               </td><td>37.23                         </td><td>1500 </td></tr>\n<tr><td>Adaptive   </td><td>1315     </td><td>185     </td><td>12.33            </td><td>71               </td><td>38.38                         </td><td>1500 </td></tr>\n</tbody>\n</table>'

# %% [markdown]
# ## Failure rate overtime

# %%
from plot_label import plot_negative_interactions_overtime,plot_cumulative_negative_interactions
from pathlib import Path
exponential = Path("../results/multirun/2024-06-11/11-39-05/0")
single = Path("../results/multirun/2024-06-11/11-39-05/1")
double = Path("../results/multirun/2024-06-11/11-39-05/2")
adaptive = Path("../results/multirun/2024-06-11/11-39-05/3")

plot_negative_interactions_overtime([("exponential", exponential),("single",single),("double",double),("adaptive", adaptive)],fuzzy=True)
plot_cumulative_negative_interactions([("exponential", exponential),("single",single),("double",double),("adaptive", adaptive)],fuzzy=True)

# %% [markdown]
# ### Outage scenario (outage duration = 2)

# %%
from plot_label import plot_negative_interactions_overtime,plot_cumulative_negative_interactions
from pathlib import Path

date_time = "2024-06-11/11-43-54"

exponential = Path(f"../results/multirun/{date_time}/0")
single = Path(f"../results/multirun/{date_time}/1")
double = Path(f"../results/multirun/{date_time}/2")
adaptive = Path(f"../results/multirun/{date_time}/3")

plot_negative_interactions_overtime([("exponential", exponential),("single",single),("double",double),("adaptive", adaptive)],fuzzy=True)
plot_cumulative_negative_interactions([("exponential", exponential),("single",single),("double",double),("adaptive", adaptive)],fuzzy=True)

# %% [markdown]
# ### Outage scenario (outage duration = 4)

# %%
from plot_label import plot_negative_interactions_overtime,plot_cumulative_negative_interactions
from pathlib import Path

date_time = "2024-06-11/11-43-54"

exponential = Path(f"../results/multirun/{date_time}/0")
single = Path(f"../results/multirun/{date_time}/1")
double = Path(f"../results/multirun/{date_time}/2")
adaptive = Path(f"../results/multirun/{date_time}/3")

plot_negative_interactions_overtime([("exponential", exponential),("single",single),("double",double),("adaptive", adaptive)],fuzzy=True)
plot_cumulative_negative_interactions([("exponential", exponential),("single",single),("double",double),("adaptive", adaptive)],fuzzy=True)

# %% [markdown]
# ### oscillatory scenario

# %%
from plot_label import plot_negative_interactions_overtime,plot_cumulative_negative_interactions
from pathlib import Path

date_time = "2024-06-12/11-13-29"

exponential = Path(f"../results/multirun/{date_time}/0")
single = Path(f"../results/multirun/{date_time}/1")
double = Path(f"../results/multirun/{date_time}/2")
adaptive = Path(f"../results/multirun/{date_time}/3")

plot_negative_interactions_overtime([("exponential", exponential),("single",single),("double",double),("adaptive", adaptive)],fuzzy=True)
plot_cumulative_negative_interactions([("exponential", exponential),("single",single),("double",double),("adaptive", adaptive)],fuzzy=True)

# %% [markdown]
# # Archive

# %% [markdown]
# ## Testing the success rate in the course of the simulation

# %%
import tabulate
from pathlib import Path
from plot_utils import load_total_positive,load_total_negative,load_total_negative,load_total_interactions


t25 = Path("../results/fuzzy/stats_at_various_timestage/t2.5")
t50 = Path("../results/fuzzy/stats_at_various_timestage/t5")
t75 = Path("../results/fuzzy/stats_at_various_timestage/t7.5")
t100 = Path("../results/fuzzy/stats_at_various_timestage/t10")

data = [ ["","Successes","Total failures","Failure ratio (%)","Expected failures", "Non expected failures",  "Ratio (%) of expected failures","Total" ],
         ["25\% of the simulation",load_total_positive(t25),load_total_negative(t25),round( 100* load_total_negative(t25)/load_total_interactions(t25),2),load_total_negative(t25,expected=True),load_total_negative(t25)-load_total_negative(t25,expected=True),round( 100* load_total_negative(t25,expected=True)/load_total_negative(t25),ndigits=2),load_total_interactions(t25)],
         ["50\% of the simulation",load_total_positive(t50),load_total_negative(t50),round( 100* load_total_negative(t50)/load_total_interactions(t50),2),load_total_negative(t50,expected=True),load_total_negative(t50)-load_total_negative(t50,expected=True),round( 100* load_total_negative(t50,expected=True)/load_total_negative(t50),ndigits=2),load_total_interactions(t50)],
         ["75\% of the simulation",load_total_positive(t75),load_total_negative(t75),round( 100* load_total_negative(t75)/load_total_interactions(t75),2),load_total_negative(t75,expected=True),load_total_negative(t75)-load_total_negative(t75,expected=True),round( 100* load_total_negative(t75,expected=True)/load_total_negative(t75),ndigits=2),load_total_interactions(t75)],
         ["Full simulation",load_total_positive(t100),load_total_negative(t100),round( 100* load_total_negative(t100)/load_total_interactions(t100),2),load_total_negative(t100,expected=True),load_total_negative(t100)-load_total_negative(t100,expected=True),round( 100* load_total_negative(t100,expected=True)/load_total_negative(t100),ndigits=2),load_total_interactions(t100)],
         ]
table = tabulate.tabulate(data, tablefmt='html')
table
# Out:
# '<table>\n<tbody>\n<tr><td>                      </td><td>Successes</td><td>Total failures</td><td>Failure ratio (%)</td><td>Expected failures</td><td>Non expected failures</td><td>Ratio (%) of expected failures</td><td>Total</td></tr>\n<tr><td>25\\% of the simulation</td><td>541      </td><td>113           </td><td>17.28            </td><td>23               </td><td>90                   </td><td>20.35                         </td><td>654  </td></tr>\n<tr><td>50\\% of the simulation</td><td>1242     </td><td>158           </td><td>11.29            </td><td>66               </td><td>92                   </td><td>41.77                         </td><td>1400 </td></tr>\n<tr><td>75\\% of the simulation</td><td>1963     </td><td>217           </td><td>9.95             </td><td>122              </td><td>95                   </td><td>56.22                         </td><td>2180 </td></tr>\n<tr><td>Full simulation       </td><td>2723     </td><td>277           </td><td>9.23             </td><t
# ...

# %% [markdown]
# Quand est-ce que surviennent les 91 premières erreurs dans le premier quart de l'expérience ?
#     Hypothèse : ça pourrait être au tout début de l'expérimentation quand les transactions sont initiés avant que le résultat des premières transactions soient disponible (période de floue)
#     Possible de faire des intervalles plus faibles (5,10,15,20) pour vérifier cela.

# %%
import tabulate
from pathlib import Path
from plot_utils import load_total_positive,load_total_negative,load_total_negative,load_total_interactions

t5 = Path("../results/fuzzy/stats_at_various_timestage/t0.5")
t10 = Path("../results/fuzzy/stats_at_various_timestage/t1.0")
t15 = Path("../results/fuzzy/stats_at_various_timestage/t1.5")
t20 = Path("../results/fuzzy/stats_at_various_timestage/t2.0")
t25 = Path("../results/fuzzy/stats_at_various_timestage/t2.5")

data = [ ["","Successes","Total failures","Failure ratio (%)","Expected failures", "Non expected failures",  "Ratio (%) of expected failures","Total" ],
         ["5\% of the simulation",load_total_positive(t5),load_total_negative(t5),round( 100* load_total_negative(t5)/load_total_interactions(t5),2),load_total_negative(t5,expected=True),load_total_negative(t5)-load_total_negative(t5,expected=True),round( 100* load_total_negative(t5,expected=True)/load_total_negative(t5),ndigits=2),load_total_interactions(t5)],
         ["10\% of the simulation",load_total_positive(t10),load_total_negative(t10),round( 100* load_total_negative(t10)/load_total_interactions(t10),2),load_total_negative(t10,expected=True),load_total_negative(t10)-load_total_negative(t10,expected=True),round( 100* load_total_negative(t10,expected=True)/load_total_negative(t10),ndigits=2),load_total_interactions(t10)],
         ["15\% of the simulation",load_total_positive(t15),load_total_negative(t15),round( 100* load_total_negative(t15)/load_total_interactions(t15),2),load_total_negative(t15,expected=True),load_total_negative(t15)-load_total_negative(t15,expected=True),round( 100* load_total_negative(t15,expected=True)/load_total_negative(t15),ndigits=2),load_total_interactions(t15)],
         ["20\% of the simulation",load_total_positive(t20),load_total_negative(t20),round( 100* load_total_negative(t20)/load_total_interactions(t20),2),load_total_negative(t20,expected=True),load_total_negative(t20)-load_total_negative(t20,expected=True),round( 100* load_total_negative(t20,expected=True)/load_total_negative(t20),ndigits=2),load_total_interactions(t20)],
         ["25\% of the simulation",load_total_positive(t25),load_total_negative(t25),round( 100* load_total_negative(t25)/load_total_interactions(t25),2),load_total_negative(t25,expected=True),load_total_negative(t25)-load_total_negative(t25,expected=True),round( 100* load_total_negative(t25,expected=True)/load_total_negative(t25),ndigits=2),load_total_interactions(t25)],
         ]
table = tabulate.tabulate(data, tablefmt='html')
table
# Out:
# '<table>\n<tbody>\n<tr><td>                      </td><td>Successes</td><td>Total failures</td><td>Failure ratio (%)</td><td>Expected failures</td><td>Non expected failures</td><td>Ratio (%) of expected failures</td><td>Total</td></tr>\n<tr><td>5\\% of the simulation </td><td>47       </td><td>43            </td><td>47.78            </td><td>0                </td><td>43                   </td><td>0.0                           </td><td>90   </td></tr>\n<tr><td>10\\% of the simulation</td><td>145      </td><td>77            </td><td>34.68            </td><td>0                </td><td>77                   </td><td>0.0                           </td><td>222  </td></tr>\n<tr><td>15\\% of the simulation</td><td>276      </td><td>92            </td><td>25.0             </td><td>7                </td><td>85                   </td><td>7.61                          </td><td>368  </td></tr>\n<tr><td>20\\% of the simulation</td><td>398      </td><td>105           </td><td>20.87            </td><
# ...
